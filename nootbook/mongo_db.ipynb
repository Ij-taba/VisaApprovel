# %%
print(ok)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(ok)
#
# NameError: name 'ok' is not defined

# %%
'''mongodb+srv://iijtabahasan:iijtabahasan@cluster1.tonfxju.mongodb.net/?appName=Cluster1 '''
